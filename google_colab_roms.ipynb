# %%
# تثبيت yolo v5
# !pip install yolov5

# %%
#استيراد المكتبة:
import yolov5
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# تحميل الملف المضغوط في جوجل كلوب وبعده تفتح الملف المضغوط بالكود
# !unzip "/content/Room-finder-in-house-map.v2i.yolov5pytorch.zip"
# Out:
# Archive:  /content/Room-finder-in-house-map.v2i.yolov5pytorch.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/24_jpg.rf.a1bbdc0b187c30dd708099a528d447d8.jpg
#  extracting: test/images/2_jpg.rf.56e4c5310a5c3bf88009c1457d883e64.jpg
#  extracting: test/images/32_jpg.rf.8d4fa8f6981b86b305defa39fbd5349f.jpg
#  extracting: test/images/34_jpg.rf.9a29b2376d49d7458dec4752f18c5db8.jpg
#    creating: test/labels/
#   inflating: test/labels/24_jpg.rf.a1bbdc0b187c30dd708099a528d447d8.txt
#   inflating: test/labels/2_jpg.rf.56e4c5310a5c3bf88009c1457d883e64.txt
#   inflating: test/labels/32_jpg.rf.8d4fa8f6981b86b305defa39fbd5349f.txt
#   inflating: test/labels/34_jpg.rf.9a29b2376d49d7458dec4752f18c5db8.txt
#    creating: train/
#    creating: train/images/
#  extracting: train/images/10_jpg.rf.504444091a375611938828bce80e14c9.jpg
# ...

# %%
#استنساخ مستودع YOLOv5
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17564, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 17564 (delta 35), reused 7 (delta 7), pack-reused 17508 (from 4)
# Receiving objects: 100% (17564/17564), 16.64 MiB | 16.80 MiB/s, done.
# Resolving deltas: 100% (12029/12029), done.

# %%
#تغيير المسار (Directory):
# %cd yolov5
# Out:
# /content/yolov5

# %%
#تثبيت جميع المكتبات الضرورية لتشغيل YOLOv5
# !pip install -r requirements.txt

# %%
# تدريب النموذج
#--img 640: يحدد حجم الصورة التي سيعالجها النموذج.
#--batch 16: يحدد عدد الصور التي يتم تدريبها في كل مرة.
#--epochs 50: يحدد عدد المرات التي سيمر فيها النموذج على مجموعة البيانات بأكملها. يمكنك زيادة هذا الرقم إذا لم تكن النتائج جيدة.
#--data '...': المسار إلى ملف data.yaml الخاص بك.
#--weights yolov5s.pt: يخبر النموذج ببدء التدريب باستخدام نموذج YOLOv5s الذي تم تدريبه مسبقًا. هذا يوفر وقتًا وجهدًا كبيرًا في التدريب.
# !python train.py --img 640 --batch 16 --epochs 50 --data '/content/data.yaml' --weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-08-30 20:27:42.522578: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756585662.565955   15224 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756585662.581134   15224 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756585662.615845   15224 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
#!python detect.py: هذا هو الأمر الذي يشغل ملف detect.py المسؤول عن الكشف عن الكائنات.
#--weights: يشير إلى مسار النموذج المدرب
#-img 640: يحدد حجم الصورة
#--conf 0.25: يحدد مستوى الثقة (confidence) للكشف. يمكنك زيادة هذا الرقم إذا كان النموذج يكتشف أشياء غير صحيحة، أو تقليله إذا كان يفوت بعض الكائنات
#-source: يشير إلى مسار الصورة التي تريد اختبار النموذج عليها
#بما أن التدريب لم يكتمل، سنستخدم ملف last.pt وليس best.pt. ملف last.pt هو النموذج الذي تم حفظه في آخر دورة تدريبية قبل التوقف، وهو النموذج الذي سنختبره. وقد انهى فقط 22
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/last.pt --img 640 --conf 0.26 --source "/content/hom.jpeg"
# حينحفظ في ملف yolo
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/last.pt'], source=/content/hom.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.26, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/hom.jpeg: 576x640 6 room-yolouv5s, 374.9ms
# Speed: 3.2ms pre-process, 374.9ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp9
